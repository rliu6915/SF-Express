cluster_20 = [41, 43, 44, 45, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 200, 227, 303, 304, 305, 306, 307, 308, 309, 382, 383, 384, 386, 387, 388, 390, 391, 392, 393, 395, 399, 403, 404, 405, 529, 667, 668, 671, 672, 673, 674, 675, 676, 677, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1560, 1574, 1639, 1640, 1641, 1642, 1683, 1739, 1747, 1748, 1817, 1818, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1982]

# %%
location.drop(location.tail(1).index,inplace=True)

# %%
len(location)
# Out:
# 2021

# %%
demand
# Out:
#      customer_code  demand
# 0           SF0001       6
# 1           SF0002     111
# 2           SF0003      37
# 3           SF0004      20
# 4           SF0005       9
# ...            ...     ...
# 2016        SF2017      69
# 2017        SF2018      63
# 2018        SF2019      51
# 2019        SF2020      63
# 2020        SF2021      82
#
# [2021 rows x 2 columns]

# %%
df = pd.merge(demand, location, on='customer_code')

# %%
df = df.reset_index()

# %%
df['cluster'] = 0

# %%
for i in range(len(df)):
    if df['index'][i] in cluster_1:
        df['cluster'][i] = 1
    if df['index'][i] in cluster_2:
        df['cluster'][i] = 2
    if df['index'][i] in cluster_3:
        df['cluster'][i] = 3
    if df['index'][i] in cluster_4:
        df['cluster'][i] = 4
    if df['index'][i] in cluster_5:
        df['cluster'][i] = 5
    if df['index'][i] in cluster_6:
        df['cluster'][i] = 6
    if df['index'][i] in cluster_7:
        df['cluster'][i] = 7
    if df['index'][i] in cluster_8:
        df['cluster'][i] = 8
    if df['index'][i] in cluster_9:
        df['cluster'][i] = 9
    if df['index'][i] in cluster_10:
        df['cluster'][i] = 10
    if df['index'][i] in cluster_11:
        df['cluster'][i] = 11
    if df['index'][i] in cluster_12:
        df['cluster'][i] = 12
    if df['index'][i] in cluster_13:
        df['cluster'][i] = 13
    if df['index'][i] in cluster_14:
        df['cluster'][i] = 14
    if df['index'][i] in cluster_15:
        df['cluster'][i] = 15
    if df['index'][i] in cluster_16:
        df['cluster'][i] = 16
    if df['index'][i] in cluster_17:
        df['cluster'][i] = 17
    if df['index'][i] in cluster_18:
        df['cluster'][i] = 18
    if df['index'][i] in cluster_19:
        df['cluster'][i] = 19
    if df['index'][i] in cluster_20:
        df['cluster'][i] = 20
# Out:
# <ipython-input-10-793a8c83e428>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cluster'][i] = 10
# <ipython-input-10-793a8c83e428>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cluster'][i] = 17
# <ipython-input-10-793a8c83e428>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cluster'][i] = 20
# <ipython-input-10-793a8c83e428>:19: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#       index customer_code  demand   longitude   latitude  cluster
# 0         0        SF0001       6  116.709478  40.203142       10
# 1         1        SF0002     111  116.709856  40.200571       10
# 2         2        SF0003      37  116.708931  40.200304       10
# 3         3        SF0004      20  116.711376  40.199473       10
# 4         4        SF0005       9  116.709838  40.199696       10
# ...     ...           ...     ...         ...        ...      ...
# 2016   2016        SF2017      69  116.562954  40.248498       15
# 2017   2017        SF2018      63  116.683110  40.327746        4
# 2018   2018        SF2019      51  116.680531  40.326654        4
# 2019   2019        SF2020      63  116.527290  40.242057       15
# 2020   2020        SF2021      82  116.528994  40.246655       15
#
# [2021 rows x 6 columns]

# %%
df['local_hub'] = 0

# %%
local_hub = list(cluster_hub['hub'])
local_hub
# Out:
# ['SF0116',
#  'SF0280',
#  'SF0541',
#  'SF0548',
#  'SF0580',
#  'SF0606',
#  'SF1111',
#  'SF1119',
#  'SF1547',
#  'SF1821',
#  'SF1858',
#  'SF1880',
#  'SF1882',
#  'SF1890',
#  'SF0165',
#  'SF0686',
#  'SF0693',
#  'SF0695',
#  'SF0705',
#  'SF0819',
#  'SF1584',
#  'SF1590',
#  'SF1686',
#  'SF0348',
#  'SF0738',
#  'SF0945',
#  'SF1546',
#  'SF1576',
#  'SF1724',
#  'SF1733',
#  'SF1751',
#  'SF1775',
#  'SF0877',
#  'SF0882',
#  'SF1176',
#  'SF1548',
#  'SF1568',
#  'SF1904',
#  'SF2018',
#  'SF0451',
#  'SF0590',
#  'SF0592',
#  'SF0721',
#  'SF1232',
#  'SF1503',
#  'SF0367',
#  'SF0369',
#  'SF0424',
#  'SF0771',
#  'SF1052',
#  'SF1156',
#  'SF1414',
#  'SF1563',
#  'SF0297',
#  'SF0615',
#  'SF1189',
#  'SF1287',
#  'SF1296',
#  'SF0186',
#  'SF0802',
#  'SF1064',
#  'SF1069',
#  'SF1077',
#  'SF1273',
#  'SF1972',
#  'SF0221',
#  'SF0980',
#  'SF1091',
#  'SF1104',
#  'SF1145',
#  'SF1283',
#  'SF2009',
#  'SF0012',
#  'SF0466',
#  'SF0468',
#  'SF0478',
# ...

# %%
for i in range(len(df)):
    if df['customer_code'][i] in local_hub:
        df['local_hub'][i] = 1
# Out:
# <ipython-input-14-6a4e9e06a109>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['local_hub'][i] = 1

# %%
df
# Out:
#       index customer_code  demand   longitude   latitude  cluster  local_hub
# 0         0        SF0001       6  116.709478  40.203142       10          0
# 1         1        SF0002     111  116.709856  40.200571       10          0
# 2         2        SF0003      37  116.708931  40.200304       10          0
# 3         3        SF0004      20  116.711376  40.199473       10          0
# 4         4        SF0005       9  116.709838  40.199696       10          0
# ...     ...           ...     ...         ...        ...      ...        ...
# 2016   2016        SF2017      69  116.562954  40.248498       15          1
# 2017   2017        SF2018      63  116.683110  40.327746        4          1
# 2018   2018        SF2019      51  116.680531  40.326654        4          0
# 2019   2019        SF2020      63  116.527290  40.242057       15          0
# 2020   2020        SF2021      82  116.528994  40.246655       15          0
#
# [2021 rows x 7 columns]

# %%
df.to_csv('data/combined.csv')
